# %% [markdown]
# ![smileyface_rotations.png](attachment:smileyface_rotations.png)

# %%
import numpy as np

x = np.array([[1], [1]])

A = np.array([[1, -1], [1, 1]])
B = np.array([[1, 2], [0, 1]])
C = np.array([[1, 0], [0, -1]])
D = np.array([[1, -1], [0, 1]])
E = np.array([[-1, 0], [0, 1]])
F = np.array([[0, 0.5], [-0.5, 0]])

# %%
A @ x
# Out:
# array([[0],
#        [2]])

# %%
B @ x
# Out:
# array([[3],
#        [1]])

# %%
C @ x
# Out:
# array([[ 1],
#        [-1]])

# %%
D @ x
# Out:
# array([[0],
#        [1]])

# %%
E @ x
# Out:
# array([[-1],
#        [ 1]])

# %%
F @ x
# Out:
# array([[ 0.5],
#        [-0.5]])

# %% [markdown]
# DCE
# ABF
